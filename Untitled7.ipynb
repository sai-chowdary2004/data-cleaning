# %% [markdown]
# <a href="https://colab.research.google.com/github/sai-chowdary2004/data-cleaning/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pands as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read
print(df.to_string())

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
g= sb.FacetGrid(df,col = "sex",hue="smoker")
g.map(plt.scatter,"total_bill","tip")
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
g= sb.FacetGrid(df,col = "sex",hue="smoker")
g.map(plt.scatter,"total_bill","tip")
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
sb.barplot(x="sex",y="tip",hue="smoker",data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
sb.regplot(x = "total_bill",y="tip",data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
sb.pairplot(df)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
selected_var =['total_bill','tip']
sb.pairplot(df,vars=selected_var)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
sb.pairplot(df,hue ='size')
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
sb.pairplot(df,hue="size",palette='rainbow')
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('tips')
sb.pairplot(df,diag_kind='kde')
plt.show()
